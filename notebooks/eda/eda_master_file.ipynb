# %% [markdown]
# # Master 2024 EDA notebook

# %% [markdown]
# # 0. Config

# %%
from matplotlib import pyplot as plt
import pandas as pd
from datetime import datetime

# %%
pd.set_option("display.max_columns", None)

# %% [markdown]
# # 1. Data

# %%
path = "../../data/MASTER_2024.csv"
df_master_stats = pd.read_csv(path)

# %% [markdown]
# # 2. Analysis

# %%
df_master_stats.head()
# Out:
#   N-NUMBER SERIAL NUMBER MFR MDL CODE  ENG MFR MDL  YEAR MFR TYPE REGISTRANT  \
# 0      100          5334      7100510      17003.0    1940.0               1
# 1    10000         10000      2130004          NaN       NaN               7
# 2    10001           A28      9601202      67007.0    1928.0               1
# 3    10004     T18208245      2072738          NaN       NaN               7
# 4    10006         BG-72      1152020      17026.0    1955.0               1
#
#                            NAME             STREET STREET2        CITY STATE  \
# 0                   BENE MARY D         PO BOX 329     NaN     KETCHUM    OK
# 1                       9AT LLC  511 WEDGEWOOD AVE     NaN   NASHVILLE    TN
# 2                STOOS ROBERT A        PO BOX 1056     NaN    LAKELAND    FL
# 3                  ETOS AIR LLC         PO BOX 288     NaN  NEW LONDON    TX
# 4  COUTCHES ROBERT HERCULES DBA    550 AIRWAY BLVD     NaN   LIVERMORE    CA
#
#      ZIP CODE REGION  COUNTY COUNTRY  LAST ACTION DATE  CERT ISSUE DATE  \
# 0  743490329       2    97.0      US          20230122       20050506.0
# 1  372035521       3    37.0      US          20240823       20240823.0
# 2  338021056       7   105.0      US          20230718       20190227.0
# 3  756820288       2   401.0      US          20230722       20130312.0
# 4  945519533       4     1.0      US          20230421       19980826.0
#
#   CERTIFICATION TYPE AIRCRAFT  TYPE ENGINE STATUS CODE  MODE S CODE  \
# 0             1             4            1          V      50002263
# 1           NaN             4            1          V      50003445
# 2             1             4            1          V      50003446
# 3           NaN             4            2          V      50003451
# 4            1U             4            1          V      50003453
#
#   FRACT OWNER  AIR WORTH DATE        OTHER NAMES(1) OTHER NAMES(2)  \
# 0                  19540430.0                   NaN            NaN
# 1                         NaN                   NaN            NaN
# 2                         NaN                   NaN            NaN
# 3                         NaN                   NaN            NaN
# 4                  19710909.0  AERO FLIGHT AVIATION            NaN
#
#   OTHER NAMES(3) OTHER NAMES(4) OTHER NAMES(5)  EXPIRATION DATE  UNIQUE ID  \
# 0            NaN            NaN            NaN       20270430.0     600060
# 1            NaN            NaN            NaN       20310831.0    1443200
# 2            NaN            NaN            NaN       20290228.0     432072
# 3            NaN            NaN            NaN       20290331.0     102879
# 4            NaN            NaN            NaN       20280229.0     480110
#
#   KIT MFR  KIT MODEL MODE S CODE HEX
# 0     NaN        NaN          A004B3
# 1     NaN        NaN          A00725
# 2     NaN        NaN          A00726
# 3     NaN        NaN          A00729
# 4     NaN        NaN          A0072B

# %%
df_master_stats.describe()
# Out:
#          ENG MFR MDL       YEAR MFR         COUNTY  LAST ACTION DATE  \
# count  271894.000000  242985.000000  297855.000000      2.997950e+05
# mean    34356.769417    1982.387958      89.857726      2.023163e+07
# std     18982.782249      54.937981     106.661735      1.599835e+04
# min         0.000000       0.000000       0.000000      1.971112e+07
# 25%     17026.000000    1966.000000      25.000000      2.023043e+07
# 50%     41508.000000    1979.000000      61.000000      2.023072e+07
# 75%     41597.000000    2005.000000     113.000000      2.023093e+07
# max     99999.000000    2024.000000     999.000000      2.024123e+07
#
#        CERT ISSUE DATE    TYPE ENGINE   MODE S CODE  AIR WORTH DATE  \
# count     2.943040e+05  299795.000000  2.997950e+05    2.674780e+05
# mean      2.015803e+07       2.244984  5.155867e+07    1.988096e+07
# std       9.552916e+04       2.461988  1.024083e+06    2.182482e+05
# min       1.940123e+07       0.000000  5.000000e+07    1.920121e+07
# 25%       2.013012e+07       1.000000  5.060158e+07    1.969033e+07
# 50%       2.019083e+07       1.000000  5.147377e+07    1.984011e+07
# 75%       2.023012e+07       2.000000  5.243439e+07    2.008011e+07
# max       2.024123e+07      11.000000  5.337370e+07    2.024123e+07
#
#        EXPIRATION DATE     UNIQUE ID
# count     2.942540e+05  2.997950e+05
# mean      2.028918e+07  6.407695e+05
# std       1.262704e+04  4.231308e+05
# min       2.018023e+07  0.000000e+00
# 25%       2.028043e+07  2.736830e+05
# 50%       2.029043e+07  5.905960e+05
# 75%       2.030033e+07  9.653215e+05
# max       2.031123e+07  1.484132e+06

# %%
list_cols_check = [
  'N-NUMBER',
  'YEAR MFR',
  'LAST ACTION DATE',
  'CERT ISSUE DATE',
  'AIR WORTH DATE',
  'EXPIRATION DATE'

]

# %%
df_master_stats.columns
# Out:
# Index(['N-NUMBER', 'SERIAL NUMBER', 'MFR MDL CODE', 'ENG MFR MDL', 'YEAR MFR',
#        'TYPE REGISTRANT', 'NAME', 'STREET', 'STREET2', 'CITY', 'STATE',
#        'ZIP CODE', 'REGION', 'COUNTY', 'COUNTRY', 'LAST ACTION DATE',
#        'CERT ISSUE DATE', 'CERTIFICATION', 'TYPE AIRCRAFT', 'TYPE ENGINE',
#        'STATUS CODE', 'MODE S CODE', 'FRACT OWNER', 'AIR WORTH DATE',
#        'OTHER NAMES(1)', 'OTHER NAMES(2)', 'OTHER NAMES(3)', 'OTHER NAMES(4)',
#        'OTHER NAMES(5)', 'EXPIRATION DATE', 'UNIQUE ID', 'KIT MFR',
#        ' KIT MODEL', 'MODE S CODE HEX'],
#       dtype='object')

# %%
df_master_stats[list_cols_check].nunique().sort_values()
# Out:
# EXPIRATION DATE        105
# YEAR MFR               114
# LAST ACTION DATE      1526
# CERT ISSUE DATE      13114
# AIR WORTH DATE       23572
# N-NUMBER            299795
# dtype: int64

# %%
#for col in list_cols_check:
#
#    print(col)
#    df_master_stats[col].hist()
#    plt.show()

# %% [markdown]
# # 3. Processing

# %%
df_master_stats_proc = df_master_stats.copy()
df_master_stats_proc = df_master_stats_proc.reset_index()

#Rename N Number to Tail number
df_master_stats_proc.rename(columns={'N-NUMBER': 'TailNumber'}, inplace=True)

# %%
list_cols = [    
  'TailNumber',
  'YEAR MFR',
  'LAST ACTION DATE',
  'CERT ISSUE DATE',
  'AIR WORTH DATE',
  'EXPIRATION DATE'
]

# %%
df_master_stats_proc= df_master_stats_proc.loc[:, list_cols]

# %%
#Data conversion.
#TODO: Keeping na as such. Do we need to exclude those records or change it to default date?
#YEAR MFR is still in float due to na values. Once default is assigned then it will becomes int.

# Convert 'CERT ISSUE DATE' from float to datetime format (YYYYMMDD). 
df_master_stats_proc['CERT ISSUE DATE'] = df_master_stats_proc['CERT ISSUE DATE'].fillna(0).apply(lambda x: datetime.strptime(str(int(x)), '%Y%m%d') if x != 0 else None)

# Convert 'AIR WORTH DATE' from float to datetime format (YYYYMMDD).
df_master_stats_proc['AIR WORTH DATE'] = df_master_stats_proc['AIR WORTH DATE'].fillna(0).apply(lambda x: datetime.strptime(str(int(x)), '%Y%m%d') if x != 0 else None)

# Convert 'EXPIRATION DATE' from float to datetime format (YYYYMMDD).
df_master_stats_proc['EXPIRATION DATE'] = df_master_stats_proc['EXPIRATION DATE'].fillna(0).apply(lambda x: datetime.strptime(str(int(x)), '%Y%m%d') if x != 0 else None)

# Convert 'LAST ACTION DATE' from float to datetime format (YYYYMMDD).
df_master_stats_proc['LAST ACTION DATE'] = df_master_stats_proc['LAST ACTION DATE'].fillna(0).apply(lambda x: datetime.strptime(str(int(x)), '%Y%m%d') if x != 0 else None)

# Convert 'YEAR MFR' from float to integer.
df_master_stats_proc['YEAR MFR'] = df_master_stats_proc['YEAR MFR'].apply(lambda x: int(x) if pd.notna(x) else None)

# %%
# Calculate NaN statistics
total_records = len(df_master_stats_proc)
nan_count = df_master_stats_proc.isna().sum()
nan_percentage = (nan_count / total_records) * 100

# Display results
nan_stats = pd.DataFrame({'NaN Count': nan_count, 'Total Records': total_records, 'NaN Percentage (%)': nan_percentage}).round(2)
print(nan_stats)
# Out:
#                   NaN Count  Total Records  NaN Percentage (%)
# TailNumber                0         299795                0.00
# YEAR MFR              56810         299795               18.95
# LAST ACTION DATE          0         299795                0.00
# CERT ISSUE DATE        5491         299795                1.83
# AIR WORTH DATE        32317         299795               10.78
# EXPIRATION DATE        5541         299795                1.85

# %%
#Derived columns
current_year = datetime.now().year
current_date = datetime.now()

# Calculate age and create a new column 'Age_Year_Mfr'
df_master_stats_proc['Age_Year_Mfr'] = df_master_stats_proc['YEAR MFR'].apply(lambda x: current_year - x if pd.notna(x) else None)

# Calculate age in days for last action, cert issue and Air worth dates
df_master_stats_proc['AgeDays_Last_Action_Date'] = df_master_stats_proc['LAST ACTION DATE'].apply(lambda x: (current_date - x).days if pd.notna(x) else None)
df_master_stats_proc['AgeDays_Cert_Issue_Date'] = df_master_stats_proc['CERT ISSUE DATE'].apply(lambda x: (current_date - x).days if pd.notna(x) else None)
df_master_stats_proc['AgeDays_Air_Worth_Date'] = df_master_stats_proc['AIR WORTH DATE'].apply(lambda x: (current_date - x).days if pd.notna(x) else None)

# Calculate days until EXPIRATION DATE
df_master_stats_proc['Days_Until_Expiration_Date'] = df_master_stats_proc['EXPIRATION DATE'].apply( lambda x: (x - current_date).days if pd.notna(x) else None)

# %%
df_master_stats_proc
# Out:
#        TailNumber  YEAR MFR LAST ACTION DATE CERT ISSUE DATE AIR WORTH DATE  \
# 0             100    1940.0       2023-01-22      2005-05-06     1954-04-30
# 1           10000       NaN       2024-08-23      2024-08-23            NaT
# 2           10001    1928.0       2023-07-18      2019-02-27            NaT
# 3           10004       NaN       2023-07-22      2013-03-12            NaT
# 4           10006    1955.0       2023-04-21      1998-08-26     1971-09-09
# ...           ...       ...              ...             ...            ...
# 299790        9ZR       NaN       2023-08-16      2023-08-16     1993-10-21
# 299791        9ZS    1974.0       2023-06-03      1996-09-23     1976-03-12
# 299792        9ZT    2001.0       2024-09-10      2022-05-09     2001-09-06
# 299793        9ZU    1959.0       2023-04-01      2017-11-14     2001-10-10
# 299794        9ZX    1986.0       2023-03-10      2023-03-10     1986-07-31
#
#        EXPIRATION DATE  Age_Year_Mfr  AgeDays_Last_Action_Date  \
# 0           2027-04-30          85.0                       785
# 1           2031-08-31           NaN                       206
# 2           2029-02-28          97.0                       608
# 3           2029-03-31           NaN                       604
# 4           2028-02-29          70.0                       696
# ...                ...           ...                       ...
# 299790      2030-08-31           NaN                       579
# 299791      2028-08-31          51.0                       653
# 299792      2029-05-31          24.0                       188
# 299793      2027-11-30          66.0                       716
# 299794      2030-03-31          39.0                       738
#
#         AgeDays_Cert_Issue_Date  AgeDays_Air_Worth_Date  \
# 0                        7255.0                 25889.0
# 1                         206.0                     NaN
# 2                        2210.0                     NaN
# 3                        4388.0                     NaN
# 4                        9700.0                 19548.0
# ...                         ...                     ...
# 299790                    579.0                 11470.0
# 299791                  10402.0                 17902.0
# 299792                   1043.0                  8593.0
# 299793                   2680.0                  8559.0
# 299794                    738.0                 14109.0
#
#         Days_Until_Expiration_Date
# 0                            773.0
# 1                           2357.0
# 2                           1443.0
# 3                           1474.0
# 4                           1078.0
# ...                            ...
# 299790                      1992.0
# 299791                      1262.0
# 299792                      1535.0
# 299793                       987.0
# 299794                      1839.0
#
# [299795 rows x 11 columns]

# %%
df_master_stats_proc
# Out:
#        TailNumber  YEAR MFR LAST ACTION DATE CERT ISSUE DATE AIR WORTH DATE  \
# 0             100    1940.0       2023-01-22      2005-05-06     1954-04-30
# 1           10000       NaN       2024-08-23      2024-08-23            NaT
# 2           10001    1928.0       2023-07-18      2019-02-27            NaT
# 3           10004       NaN       2023-07-22      2013-03-12            NaT
# 4           10006    1955.0       2023-04-21      1998-08-26     1971-09-09
# ...           ...       ...              ...             ...            ...
# 299790        9ZR       NaN       2023-08-16      2023-08-16     1993-10-21
# 299791        9ZS    1974.0       2023-06-03      1996-09-23     1976-03-12
# 299792        9ZT    2001.0       2024-09-10      2022-05-09     2001-09-06
# 299793        9ZU    1959.0       2023-04-01      2017-11-14     2001-10-10
# 299794        9ZX    1986.0       2023-03-10      2023-03-10     1986-07-31
#
#        EXPIRATION DATE  Age_Year_Mfr  AgeDays_Last_Action_Date  \
# 0           2027-04-30          85.0                       785
# 1           2031-08-31           NaN                       206
# 2           2029-02-28          97.0                       608
# 3           2029-03-31           NaN                       604
# 4           2028-02-29          70.0                       696
# ...                ...           ...                       ...
# 299790      2030-08-31           NaN                       579
# 299791      2028-08-31          51.0                       653
# 299792      2029-05-31          24.0                       188
# 299793      2027-11-30          66.0                       716
# 299794      2030-03-31          39.0                       738
#
#         AgeDays_Cert_Issue_Date  AgeDays_Air_Worth_Date  \
# 0                        7255.0                 25889.0
# 1                         206.0                     NaN
# 2                        2210.0                     NaN
# 3                        4388.0                     NaN
# 4                        9700.0                 19548.0
# ...                         ...                     ...
# 299790                    579.0                 11470.0
# 299791                  10402.0                 17902.0
# 299792                   1043.0                  8593.0
# 299793                   2680.0                  8559.0
# 299794                    738.0                 14109.0
#
#         Days_Until_Expiration_Date
# 0                            773.0
# 1                           2357.0
# 2                           1443.0
# 3                           1474.0
# 4                           1078.0
# ...                            ...
# 299790                      1992.0
# 299791                      1262.0
# 299792                      1535.0
# 299793                       987.0
# 299794                      1839.0
#
# [299795 rows x 11 columns]

# %% [markdown]
# # 4. Export

# %%
path = "../../outputs/raw/"

# %%
df_dd = df_master_stats.dtypes.to_frame().reset_index()
df_dd.columns = ["column", "dtype"]
df_dd.to_csv(f"{path}MasterData_dictionary.csv", index=False)

# %%
path = "../../outputs/proc/"

# %%
df_dd = df_master_stats_proc.dtypes.to_frame().reset_index()
df_dd.columns = ["column", "dtype"]
df_dd.to_csv(f"{path}MasterData_dictionary.csv", index=False)

# %%
df_master_stats_proc.to_csv(f"{path}FlightMasterData.csv", index=False)
